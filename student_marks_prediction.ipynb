# %% [markdown]
# <a href="https://colab.research.google.com/github/AakashNaseer/AakashNaseer/blob/main/student_marks_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML project

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scikit_Learn as skl

# %% [markdown]
# load data **set**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9ce5b5ba-45a4-44f6-9f83-59324e378ea7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9ce5b5ba-45a4-44f6-9f83-59324e378ea7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("Student_Marks.csv")
df.head()
# Out:
#    number_courses  time_study   Marks
# 0               3       4.508  19.202
# 1               4       0.096   7.734
# 2               4       3.133  13.811
# 3               6       7.909  53.018
# 4               8       7.811  55.299

# %%
print(df.shape)
df.info()
df.describe()
# Out:
# (100, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   number_courses  100 non-null    int64
#  1   time_study      100 non-null    float64
#  2   Marks           100 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB
#        number_courses  time_study       Marks
# count      100.000000  100.000000  100.000000
# mean         5.290000    4.077140   24.417690
# std          1.799523    2.372914   14.326199
# min          3.000000    0.096000    5.609000
# 25%          4.000000    2.058500   12.633000
# 50%          5.000000    4.022000   20.059500
# 75%          7.000000    6.179250   36.676250
# max          8.000000    7.957000   55.299000

# %%
df.isnull().sum()
# Out:
# number_courses    0
# time_study        0
# Marks             0
# dtype: int64

# %% [markdown]
# **ploting the data visualization**

# %%
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)

plt.scatter(df['time_study'], df['Marks'], color="red")
plt.xlabel("time-study")
plt.ylabel("Marks")
plt.title("time study Vs Marks")

plt.subplot(1,2,2)
plt.scatter(df["number_courses"], df["Marks"], color="green")
plt.xlabel("number_courses")
plt.ylabel("Marks")
plt.title("courses Vs Marks")

plt.tight_layout()
plt.show()

# %% [markdown]
# * **spliting features**

# %%
x = df[["number_courses", "time_study"]]
y = df["Marks"]

print(x.head())
print((y.head))
# Out:
#    number_courses  time_study
# 0               3       4.508
# 1               4       0.096
# 2               4       3.133
# 3               6       7.909
# 4               8       7.811
# <bound method NDFrame.head of 0     19.202
# 1      7.734
# 2     13.811
# 3     53.018
# 4     55.299
#        ...
# 95    19.128
# 96     5.609
# 97    41.444
# 98    12.027
# 99    32.357
# Name: Marks, Length: 100, dtype: float64>

# %% [markdown]
# train test split
